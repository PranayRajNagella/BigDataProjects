# %%
#List_remove_append
input_list=['SAS', 'R', 'PYTHON', 'SPSS']
input_list.remove("SPSS")
input_list.append('SPARK')
print(input_list)
# Out:
# ['SAS', 'R', 'PYTHON', 'SPARK']

# %%
#String to List Conversion
input_str = 'I love Data Science & Python'
result_list=input_str.split("&")
print(result_list)
# Out:
# ['I love Data Science ', ' Python']

# %%
#List to String Conversion
list=['Pythons syntax is easy to learn', 'Pythons syntax is very clear']
text_char=" & "
print(text_char.join(list));
# Out:
# Pythons syntax is easy to learn & Pythons syntax is very clear

# %%
#Nested List
input_list = [['SAS','R'],['Tableau','SQL'],['Python','Java']]
print(input_list[2][0])
# Out:
# Python

# %%
#It’s the time to disco
t = ("disco", 12, 4.5)
print(t[0][2])
# Out:
# s

# %%
#String Formatting
nametext=str(input())
print(nametext.lower().replace(" ","_"))
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <command-255885374563613> in <module>
#       1 #String Formatting
# ----> 2 nametext=str(input())
#       3 print(nametext.lower().replace(" ","_"))
#
# /databricks/python/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     855         """
#     856         if not self._allow_stdin:
# --> 857             raise StdinNotImplementedError(
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
#String Palindrome
mystring=str(input())
copyofString=mystring
print(mystring[::-1])
if(mystring==copyofString):
    print(1)
else:
    print(0)
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <command-255885374563614> in <module>
#       1 #String Palindrome
# ----> 2 mystring=str(input())
#       3 copyofString=mystring
#       4 print(mystring[::-1])
#       5 if(mystring==copyofString):
#
# /databricks/python/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     855         """
#     856         if not self._allow_stdin:
# --> 857             raise StdinNotImplementedError(
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
#ReverseWords
mysentence=str(input())
words=mysentence.split(" ")
finalsentence=""

for word in words:
    finalsentence=finalsentence+word[::-1]+' '

print(finalsentence)
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <command-255885374563615> in <module>
#       1 #ReverseWords
# ----> 2 mysentence=str(input())
#       3 words=mysentence.split(" ")
#       4 finalsentence=""
#       5
#
# /databricks/python/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     855         """
#     856         if not self._allow_stdin:
# --> 857             raise StdinNotImplementedError(
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
